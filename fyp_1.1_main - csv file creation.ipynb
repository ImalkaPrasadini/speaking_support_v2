# %%
# !pip install pickle-mixin
# Out:
# Collecting pickle-mixin
#   Downloading pickle-mixin-1.0.2.tar.gz (5.1 kB)
# Building wheels for collected packages: pickle-mixin
#   Building wheel for pickle-mixin (setup.py): started
#   Building wheel for pickle-mixin (setup.py): finished with status 'done'
#   Created wheel for pickle-mixin: filename=pickle_mixin-1.0.2-py3-none-any.whl size=6003 sha256=ea8e355c819e8a7d19f2efe43848e9b8bc9edc0e7a4d5446db4f0c1cb84dafa4
#   Stored in directory: c:\users\acer\appdata\local\pip\cache\wheels\2a\a4\6c\83bfbc3b94f1bb43d634b07a6a893fd437a45c58b29aea5142
# Successfully built pickle-mixin
# Installing collected packages: pickle-mixin
# Successfully installed pickle-mixin-1.0.2

# %%
# !pip install praat-parselmouth
# Out:
# Collecting praat-parselmouth
#   Using cached praat_parselmouth-0.4.0-cp38-cp38-win_amd64.whl (8.9 MB)
# Requirement already satisfied: numpy>=1.7.0 in c:\programdata\anaconda3\lib\site-packages (from praat-parselmouth) (1.19.2)
# Installing collected packages: praat-parselmouth
# Successfully installed praat-parselmouth-0.4.0

# %%
import parselmouth
from parselmouth.praat import call, run_file
import glob
import pandas as pd
import numpy as np
import scipy
from scipy.stats import binom
from scipy.stats import ks_2samp
from scipy.stats import ttest_ind
import os
import pickle
import matplotlib.pyplot as plt

# %%
p = r"F:/project/FYP_1.1_pro"

# %%
def run_praat_expert(p):
    
    arrarOfData = []
#     E:\jupyter_project\FYP_1.1_pro\audio\copy_expert
    dir_lists = os.listdir('F:/project/FYP_1.1_pro/audio/copy_expert/')
    for dir_list in dir_lists:
        file_list = os.listdir('F:/project/FYP_1.1_pro/audio/copy_expert/' + dir_list)
        for audiofile in file_list:
            file_format = audiofile.split('.')[1]
#             print(file_format)
            if(file_format == "wav"):
                m = audiofile.split('.')[0]
                
                sound=p+"/"+"audio"+"/"+"copy_expert"+"/"+dir_list+"/"+m+".wav"
                sourcerun=p+"/"+"myprosody"+"/"+"dataset"+"/"+"essen"+"/"+"myspsolution.praat"
                path=p+"/"+"myprosodytest"+"/"+"expert"
#                 ppp =p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"+dir_list+"/"
                try:
                    objects= run_file(sourcerun, -20, 2, 0.3, "yes",sound,path, 80, 400, 0.01, capture_output=True)
    #                 print (objects[0]) # This will print the info from the sound object, and objects[0] is a parselmouth.Sound object
                    z1=str( objects[1]) # This will print the info from the textgrid object, and objects[1] is a parselmouth.Data object with a TextGrid inside
                    z2=z1.strip().split()
                    z3=int(z2[13]) # will be the integer number 10
                    z4=float(z2[14]) # will be the floating point number 8.3
                    db= binom.rvs(n=10,p=z4,size=10000)
                    a=np.array(db)
                    b=np.mean(a)*100/10
                    del z2[-1]
                    aaa = str(audiofile)
                    z2.append(format(b,'.2f'))
                    z2.append(aaa)
                    arrarOfData.append(z2)
    #                 print (dataset.T)
                except:
                    print ("Try again the sound of the audio was not clear")
    dff = pd.DataFrame(arrarOfData,columns=("number_of_syllables","number_of_pauses","rate_of_speech","articulation_rate","speaking_duration","original_duration","balance","f0_mean","f0_std","f0_median","f0_min","f0_max","f0_quantile25","f0_quan75","pronunciation_score_percentage","name_of_audio"))
#     print(arrarOfData)
    dff.to_csv('audio/metadata/expert_metadata.csv')
    print("done")

# %%
run_praat_expert(p)
# Out:
# done

# %%
def run_praat_train(p):
    
    arrarOfData = []
    dir_lists = os.listdir('F:/project/FYP_1.1_pro/audio/copy_train/')
    for dir_list in dir_lists:
        file_list = os.listdir('F:/project/FYP_1.1_pro/audio/copy_train/' + dir_list)
        for audiofile in file_list:
            file_format = audiofile.split('.')[1]
#             print(file_format)
            if(file_format == "wav"):
                m = audiofile.split('.')[0]
                
                sound=p+"/"+"audio"+"/"+"copy_train"+"/"+dir_list+"/"+m+".wav"
                sourcerun=p+"/"+"myprosody"+"/"+"dataset"+"/"+"essen"+"/"+"myspsolution.praat"
                path=p+"/"+"myprosodytest"+"/"+"train"
                
                try:
                    objects= run_file(sourcerun, -20, 2, 0.3, "yes",sound,path, 80, 400, 0.01, capture_output=True)
    #                 print (objects[0]) # This will print the info from the sound object, and objects[0] is a parselmouth.Sound object
                    z1=str( objects[1]) # This will print the info from the textgrid object, and objects[1] is a parselmouth.Data object with a TextGrid inside
                    z2=z1.strip().split()
                    z3=int(z2[13]) # will be the integer number 10
                    z4=float(z2[14]) # will be the floating point number 8.3
                    db= binom.rvs(n=10,p=z4,size=10000)
                    a=np.array(db)
                    b=np.mean(a)*100/10
                    del z2[-1]
                    aaa = str(audiofile)
                    z2.append(format(b,'.2f'))
                    z2.append(aaa)
                    arrarOfData.append(z2)
                except:
                    print ("Try again the sound of the audio was not clear")
    dff = pd.DataFrame(arrarOfData,columns=("number_of_syllables","number_of_pauses","rate_of_speech","articulation_rate","speaking_duration","original_duration","balance","f0_mean","f0_std","f0_median","f0_min","f0_max","f0_quantile25","f0_quan75","pronunciation_score_percentage","name_of_audio"))
#     print(arrarOfData)
    dff.to_csv('audio/metadata/train_metadata.csv')
    print("done")

# %%
run_praat_train(p)
# Out:
# done

# %%
## train data set file
train_metadata = pd.read_csv('audio/metadata/train_metadata.csv') 
train_metadata.head()
# Out:
#    Unnamed: 0  number_of_syllables  number_of_pauses  rate_of_speech  \
# 0           0                  133                10               3
# 1           1                  145                13               4
# 2           2                  126                21               3
# 3           3                  160                 7               4
# 4           4                  127                19               3
#
#    articulation_rate  speaking_duration  original_duration  balance  f0_mean  \
# 0                  4               31.6               39.5      0.8   233.24
# 1                  4               33.0               40.9      0.8   262.39
# 2                  5               27.5               45.4      0.6   246.01
# 3                  5               33.1               38.1      0.9   270.39
# 4                  4               33.9               50.3      0.7   235.25
#
#    f0_std  f0_median  f0_min  f0_max  f0_quantile25  f0_quan75  \
# 0   35.64      230.9      95     383            215        255
# 1   54.99      257.9      80     418            229        297
# 2   64.38      228.5      80     415            204        300
# 3   42.15      266.0      87     412            242        302
# 4   56.89      224.8      71     420            202        269
#
#    pronunciation_score_percentage  name_of_audio
# 0                           90.00  S100_P1_F.wav
# 1                          100.00   S13_P1_F.wav
# 2                           69.84   S15_P1_F.wav
# 3                           94.97    S1_P1_F.wav
# 4                           70.22    S2_P1_F.wav

# %%
## expert data set file
expert_metadata = pd.read_csv('audio/metadata/expert_metadata.csv') 
expert_metadata.head()
# Out:
#    Unnamed: 0  number_of_syllables  number_of_pauses  rate_of_speech  \
# 0           0                  139                11               3
# 1           1                  584                37               4
# 2           2                  223                15               4
# 3           3                  202                16               4
# 4           4                  148                 8               4
#
#    articulation_rate  speaking_duration  original_duration  balance  f0_mean  \
# 0                  5               30.8               43.6      0.7   227.95
# 1                  5              115.2              148.2      0.8   206.90
# 2                  5               45.5               57.2      0.8   231.78
# 3                  5               42.1               54.2      0.8   235.23
# 4                  5               28.4               36.6      0.8   200.50
#
#    f0_std  f0_median  f0_min  f0_max  f0_quantile25  f0_quan75  \
# 0   56.11      219.3      73     420            191        266
# 1   47.11      203.8      75     420            174        227
# 2   57.89      221.6      72     420            196        262
# 3   56.20      224.8      75     420            200        272
# 4   58.06      197.8      71     396            173        225
#
#    pronunciation_score_percentage name_of_audio
# 0                           85.03     E2_P1.wav
# 1                           94.96     E3_P1.wav
# 2                           94.88    E2_P10.wav
# 3                           95.07    E2_P11.wav
# 4                           94.97    E1_P12.wav

# %%
# from tqdm import tqdm

# %%
# expert_audio_dataset_path = 'E:/jupyter_project/FYP_1.0_Project/audio/metadata'

# %%
# df_meal = pd.read_csv('audio/metadata/expert_metadata.csv') 
# for index_num,row in tqdm(expert_metadata.iterrows()):

#     file_name = os.path.join(os.path.abspath(expert_audio_dataset_path)+'/',str(row["name_of_audio"]))
#     print(file_name)
# #     data=spectro_creator(file_name)

# %%
#### Extracting MFCC's For every audio file for students
import pandas as pd
import os
import librosa

audio_dataset_path='F:/project/FYP_1.1_pro/audio/copy_train/'
metadata=pd.read_csv('F:/project/FYP_1.1_pro/audio/metadata/train_metadata1.csv')
metadata.head()
# Out:
#    Unnamed: 0  number_of_syllables  number_of_pauses  rate_of_speech  \
# 0           0                  133                10               3
# 1           1                  145                13               4
# 2           2                  126                21               3
# 3           3                  160                 7               4
# 4           4                  127                19               3
#
#    articulation_rate  speaking_duration  original_duration  balance  f0_mean  \
# 0                  4               31.6               39.5      0.8   233.24
# 1                  4               33.0               40.9      0.8   262.39
# 2                  5               27.5               45.4      0.6   246.01
# 3                  5               33.1               38.1      0.9   270.39
# 4                  4               33.9               50.3      0.7   235.25
#
#    f0_std  f0_median  f0_min  f0_max  f0_quantile25  f0_quan75  \
# 0   35.64      230.9      95     383            215        255
# 1   54.99      257.9      80     418            229        297
# 2   64.38      228.5      80     415            204        300
# 3   42.15      266.0      87     412            242        302
# 4   56.89      224.8      71     420            202        269
#
#    pronunciation_score_percentage  name_of_audio  fold
# 0                           90.00  S100_P1_F.wav     1
# 1                          100.00   S13_P1_F.wav     1
# 2                           69.84   S15_P1_F.wav     1
# 3                           94.97    S1_P1_F.wav     1
# 4                           70.22    S2_P1_F.wav     1

# %%
def features_extractor(file):
    audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
    mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
    mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
    
    return mfccs_scaled_features

# %%
import numpy as np
from tqdm import tqdm
### Iterate through every audio file and extract features 
### using Mel-Frequency Cepstral Coefficients
extracted_features=[]
for index_num,row in tqdm(metadata.iterrows()):
    file_name = os.path.join(os.path.abspath(audio_dataset_path),'fold'+str(row["fold"])+'/',str(row["name_of_audio"]))
    final_class_labels=row["pronunciation_score_percentage"]
    data=features_extractor(file_name)
    extracted_features.append([data,final_class_labels])
# Out:
# 489it [06:38,  1.23it/s]

# %%
### converting extracted_features to Pandas dataframe
extracted_features_df=pd.DataFrame(extracted_features,columns=['feature','class'])
extracted_features_df.head()
# Out:
#                                              feature   class
# 0  [-350.74597, 101.56913, 10.9433365, 27.206776,...   90.00
# 1  [-346.6668, 112.681076, 1.1907796, 12.289317, ...  100.00
# 2  [-362.7636, 108.308716, -10.139892, 30.08563, ...   69.84
# 3  [-319.31256, 127.4388, 8.366039, -0.7263512, -...   94.97
# 4  [-392.04468, 92.2704, 13.936693, 16.60574, 0.8...   70.22

# %%
extracted_features_df.to_csv('F:/project/FYP_1.1_pro/audio/metadata/train_final_metadata.csv')

# %%
# MFCCs genration for experts

# %%
#### Extracting MFCC's For every audio file for experts
import pandas as pd
import os
import librosa

audio_dataset_path='F:/project/FYP_1.1_pro/audio/copy_expert/'
metadata=pd.read_csv('F:/project/FYP_1.1_pro/audio/metadata/expert_metadata1.csv')
metadata.head()
# Out:
#    Unnamed: 0  number_of_syllables  number_of_pauses  rate_of_speech  \
# 0           0                  139                11               3
# 1           1                  584                37               4
# 2           2                  223                15               4
# 3           3                  202                16               4
# 4           4                  148                 8               4
#
#    articulation_rate  speaking_duration  original_duration  balance  f0_mean  \
# 0                  5               30.8               43.6      0.7   227.95
# 1                  5              115.2              148.2      0.8   206.90
# 2                  5               45.5               57.2      0.8   231.78
# 3                  5               42.1               54.2      0.8   235.23
# 4                  5               28.4               36.6      0.8   200.50
#
#    f0_std  f0_median  f0_min  f0_max  f0_quantile25  f0_quan75  \
# 0   56.11      219.3      73     420            191        266
# 1   47.11      203.8      75     420            174        227
# 2   57.89      221.6      72     420            196        262
# 3   56.20      224.8      75     420            200        272
# 4   58.06      197.8      71     396            173        225
#
#    pronunciation_score_percentage name_of_audio  fold
# 0                           85.11     E2_P1.wav     1
# 1                           94.99     E3_P1.wav     1
# 2                           94.98    E2_P10.wav    10
# 3                           94.98    E2_P11.wav    11
# 4                           95.02    E1_P12.wav    12

# %%
def features_extractor(file):
    audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
    mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
    mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
    
    return mfccs_scaled_features

# %%
import numpy as np
from tqdm import tqdm
### Iterate through every audio file and extract features 
### using Mel-Frequency Cepstral Coefficients
extracted_features=[]
for index_num,row in tqdm(metadata.iterrows()):
    file_name = os.path.join(os.path.abspath(audio_dataset_path),'fold'+str(row["fold"])+'/',str(row["name_of_audio"]))
    final_class_labels=row["pronunciation_score_percentage"]
    data=features_extractor(file_name)
    extracted_features.append([data,final_class_labels])
# Out:
# 19it [00:21,  1.12s/it]

# %%
### converting extracted_features to Pandas dataframe
extracted_features_df=pd.DataFrame(extracted_features,columns=['feature','class'])
extracted_features_df.head()
# Out:
#                                              feature  class
# 0  [-364.22656, 133.04326, -24.707306, 8.948652, ...  85.11
# 1  [-379.86017, 119.4718, -3.163177, 25.166592, -...  94.99
# 2  [-353.5439, 145.00945, -31.72263, 8.87748, 17....  94.98
# 3  [-352.76407, 136.59334, -31.263487, 8.083315, ...  94.98
# 4  [-427.30124, 129.09596, -3.9694078, 8.760965, ...  95.02

# %%
extracted_features_df.to_csv('F:/project/FYP_1.1_pro/audio/metadata/expert_mfcc_metadata.csv')

# %%
# Start trian model

# %%
#### Extracting MFCC's For every audio file for experts
import pandas as pd
import os
import librosa

# audio_dataset_path='F:/project/FYP_1.1_pro/audio/copy_expert/'
metadata=pd.read_csv('F:/project/FYP_1.1_pro/audio/metadata/final/final_metadata.csv')
metadata.head()
# Out:
#    Unnamed: 0                                            feature   class
# 0           0  [-3.50745972e+02  1.01569130e+02  1.09433365e+...   90.00
# 1           1  [-3.46666809e+02  1.12681076e+02  1.19077957e+...  100.00
# 2           2  [-3.62763611e+02  1.08308716e+02 -1.01398916e+...   69.84
# 3           3  [-3.1931256e+02  1.2743880e+02  8.3660393e+00 ...   94.97
# 4           4  [-3.9204468e+02  9.2270401e+01  1.3936693e+01 ...   70.22
